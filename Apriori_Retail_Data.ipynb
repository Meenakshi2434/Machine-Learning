# %% [markdown]
# <a href="https://colab.research.google.com/github/Meenakshi2434/Machine-Learning/blob/main/Apriori_Retail_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
df= pd.read_csv('/content/Online Retail.csv')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  ...  UnitPrice CustomerID         Country
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER  ...       2.55    17850.0  United Kingdom
# 1    536365     71053                  WHITE METAL LANTERN  ...       3.39    17850.0  United Kingdom
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER  ...       2.75    17850.0  United Kingdom
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE  ...       3.39    17850.0  United Kingdom
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.  ...       3.39    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
df['Description']=df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo']=df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]
df
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 175967    551995     22980  ...    15287.0  United Kingdom
# 175968    551995     22982  ...    15287.0  United Kingdom
# 175969    551995     22983  ...    15287.0  United Kingdom
# 175970    551995     22993  ...    15287.0  United Kingdom
# 175971    551995     22998  ...        NaN             NaN
#
# [172742 rows x 8 columns]

# %%
basket = (df[df['Country'] == 'France']).groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')

# %%
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC METAL HEART DECORATION
# InvoiceNo                            ...
# 536370                          0.0  ...                          0.0
# 536852                          0.0  ...                          0.0
# 536974                          0.0  ...                          0.0
# 537065                          0.0  ...                          0.0
# 537463                          0.0  ...                          0.0
# ...                             ...  ...                          ...
# 551545                          0.0  ...                          0.0
# 551552                          0.0  ...                          0.0
# 551649                          0.0  ...                          0.0
# 551652                          0.0  ...                          0.0
# 551887                          0.0  ...                          0.0
#
# [117 rows x 747 columns]

# %%
def encode_units(x):
  if x<=0:
    return 0
  if x>=0:
    return 1
basket_sets= basket.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)
basket_sets
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC METAL HEART DECORATION
# InvoiceNo                            ...
# 536370                            0  ...                            0
# 536852                            0  ...                            0
# 536974                            0  ...                            0
# 537065                            0  ...                            0
# 537463                            0  ...                            0
# ...                             ...  ...                          ...
# 551545                            0  ...                            0
# 551552                            0  ...                            0
# 551649                            0  ...                            0
# 551652                            0  ...                            0
# 551887                            0  ...                            0
#
# [117 rows x 746 columns]

# %%
frequent_itemsets =apriori(basket_sets, min_support=0.07, use_colnames=True)
rules= association_rules(frequent_itemsets, metric='lift', min_threshold= 1)
rules.head()
# Out:
#                           antecedents  ... zhangs_metric
# 0              (DOLLY GIRL LUNCH BOX)  ...      0.911111
# 1                (SPACEBOY LUNCH BOX)  ...      0.947195
# 2  (LUNCH BOX WITH CUTLERY RETROSPOT)  ...      0.755319
# 3           (LUNCH BAG RED RETROSPOT)  ...      0.731959
# 4                (LUNCH BAG WOODLAND)  ...      0.955882
#
# [5 rows x 10 columns]

# %%
rules[ (rules['lift'] >= 4) & (rules['confidence'] >= 0.8)]
# Out:
#                                           antecedents  ... zhangs_metric
# 38               (SET/20 RED RETROSPOT PAPER NAPKINS)  ...      0.931271
# 40               (SET/20 RED RETROSPOT PAPER NAPKINS)  ...      0.939357
# 42                    (SET/6 RED SPOTTY PAPER PLATES)  ...      0.966917
# 43                      (SET/6 RED SPOTTY PAPER CUPS)  ...      0.987711
# 50  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...  ...      0.930000
# 51  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...  ...      0.946524
# 52  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...  ...      0.961397
# 53               (SET/20 RED RETROSPOT PAPER NAPKINS)  ...      0.951486
#
# [8 rows x 10 columns]
